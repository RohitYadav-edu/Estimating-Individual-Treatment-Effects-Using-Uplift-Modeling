# %%
import os, sys
PROJECT_ROOT = "/Users/rohityadav/Desktop/Git Projects/ml-uplift-modeling-criteo"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

import pandas as pd
from lambda_app.handler import handler

path = "/Users/rohityadav/Desktop/Git Projects/ml-uplift-modeling-criteo/data/criteo-uplift-v2.1-100K-balanced.csv"
df = pd.read_csv(path)

sample = df.sample(2, random_state = 42)[[c for c in df.columns if c.startswith('f')]]

event = {
    'instances': sample.to_dict(orient = 'records')
}

print(handler(event, None))
# Out:
# {'statusCode': 200, 'headers': {'Content-Type': 'application/json'}, 'body': '{"predictions": [{"p_treated": 0.009632119867053297, "p_control": 0.008449366880645733, "uplift": 0.0011827529864075637}, {"p_treated": 0.1747946097117602, "p_control": 0.08550043288566969, "uplift": 0.0892941768260905}], "model": "tlearner_logreg_v1", "n": 2}'}
